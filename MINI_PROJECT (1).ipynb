# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/newgdp.csv",encoding='latin')

# %%
data.shape
# Out:
# (10, 50)

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#      Year  Population  Population growth(%)  Area(sqkm)  Population density  \
# 0  YR2011  1250287939              1.288513     3287260          420.520700
# 1  YR2012  1265780243              1.231485     3287260          425.731367
# 2  YR2013  1280842119              1.182904     3287260          430.797265
# 3  YR2014  1295600768              1.145673     3287260          435.761175
# 4  YR2015  1310152392              1.116896     3287260          440.655455
#
#    Poverty headcount (% of population)      GNI(US$)  GNI per capita(US$)  \
# 0                                22.50  1.700000e+12                 1360
# 1                                21.70  1.870000e+12                 1480
# 2                                21.01  1.940000e+12                 1520
# 3                                19.78  2.020000e+12                 1560
# 4                                18.70  2.100000e+12                 1600
#
#    Income share held by lowest 20%  Life expectancy  \
# ...

# %%
data.tail()
# Out:
#      Year  Population  Population growth(%)  Area(sqkm)  Population density  \
# 5  YR2016  1324517250              1.090459     3287260          445.486918
# 6  YR2017  1338676779              1.063359     3287260          450.249321
# 7  YR2018  1352642283              1.037828     3287260          454.946466
# 8  YR2019  1366417756              1.013261     3287260          459.579696
# 9  YR2020  1380004385              0.989414     3287260          464.149410
#
#    Poverty headcount (% of population)      GNI(US$)  GNI per capita(US$)  \
# 5                                18.10  2.230000e+12                 1680
# 6                                13.40  2.440000e+12                 1820
# 7                                11.10  2.710000e+12                 2010
# 8                                10.00  2.870000e+12                 2100
# 9                                10.99  2.640000e+12                 1910
#
#    Income share held by lowest 20%  Life expectancy  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 50 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Year                                         10 non-null     object
#  1   Population                                   10 non-null     int64
#  2   Population growth(%)                         10 non-null     float64
#  3   Area(sqkm)                                   10 non-null     int64
#  4   Population density                           10 non-null     float64
#  5   Poverty headcount (% of population)          10 non-null     float64
#  6   GNI(US$)                                     10 non-null     float64
#  7   GNI per capita(US$)                          10 non-null     int64
#  8   Income share held by lowest 20%              6 non-null      float64
# ...

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.columns = data.columns.str.replace(',', '')

# %%
data.columns = data.columns.str.replace('%', 'perc')

# %%
data.columns = data.columns.str.replace('$', 'dr')
# Out:
# <ipython-input-11-48524286a774>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.replace('$', 'dr')

# %%
data.columns = data.columns.str.replace('.', '')
# Out:
# <ipython-input-12-d2e791ab92f4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.replace('.', '')

# %%
data.columns
# Out:
# Index(['Year', 'Population', 'Population_growth(perc)', 'Area(sqkm)',
#        'Population_density', 'Poverty_headcount_(perc_of_population)',
#        'GNI(USdr)', 'GNI_per_capita(USdr)',
#        'Income_share_held_by_lowest_20perc', 'Life_expectancy',
#        'Fertility_rate_total_(births_per_woman)', 'Adolescent_fertility_rate',
#        'Births_attended_by_skilled_health_staff', 'Infant_Mortality_rate',
#        'Underweight_for_age_(perc_of_under_5)',
#        'Immunization_measles_(perc_of_children)', 'Primary_completion_rate',
#        'School_enrollmentPrimary(perc)', 'School_enrollmentSecondary_(perc_)',
#        'gender_parity_index', 'Forest_area_(sq_km)',
#        'Terrestrial_marine_areas', 'Annual_freshwater_withdrawals',
#        'Urban_population_growth_(annual_perc)', 'Energy_use_(kg_of_oil_)',
#        'CO2_(metric_tons_per_capita)', 'Electricity_use(kWh_per_capita)',
#        'GDP_(current_USdr)', 'GDP_growth_(annual_perc)',
# ...

# %%
data.describe().round(3)
# Out:
#          Population  Population_growth(perc)  Area(sqkm)  Population_density  \
# count  1.000000e+01                   10.000        10.0              10.000
# mean   1.316492e+09                    1.116   3287260.0             442.788
# std    4.357882e+07                    0.097         0.0              14.657
# min    1.250288e+09                    0.989   3287260.0             420.521
# 25%    1.284532e+09                    1.044   3287260.0             432.038
# 50%    1.317335e+09                    1.104   3287260.0             443.071
# 75%    1.349151e+09                    1.174   3287260.0             453.772
# max    1.380004e+09                    1.289   3287260.0             464.149
#
#        Poverty_headcount_(perc_of_population)     GNI(USdr)  \
# count                                  10.000  1.000000e+01
# mean                                   16.728  2.252000e+12
# std                                     4.858  3.948220e+11
# ...

# %%
data.isnull().sum()
# Out:
# Year                                            0
# Population                                      0
# Population_growth(perc)                         0
# Area(sqkm)                                      0
# Population_density                              0
# Poverty_headcount_(perc_of_population)          0
# GNI(USdr)                                       0
# GNI_per_capita(USdr)                            0
# Income_share_held_by_lowest_20perc              4
# Life_expectancy                                 0
# Fertility_rate_total_(births_per_woman)         0
# Adolescent_fertility_rate                       0
# Births_attended_by_skilled_health_staff         8
# Infant_Mortality_rate                           0
# Underweight_for_age_(perc_of_under_5)           7
# Immunization_measles_(perc_of_children)         0
# Primary_completion_rate                         2
# School_enrollmentPrimary(perc)                  1
# School_enrollmentSecondary_(perc_)              0
# ...

# %%
data=data.drop(['Income_share_held_by_lowest_20perc'], axis=1)

# %%
data=data.drop(['Underweight_for_age_(perc_of_under_5)'], axis=1)

# %%
data=data.drop(['Time_required_to_start_a_business_(days)'], axis=1)

# %%
data=data.drop(['Births_attended_by_skilled_health_staff'], axis=1)

# %%
data.isnull().sum()
# Out:
# Year                                            0
# Population                                      0
# Population_growth(perc)                         0
# Area(sqkm)                                      0
# Population_density                              0
# Poverty_headcount_(perc_of_population)          0
# GNI(USdr)                                       0
# GNI_per_capita(USdr)                            0
# Life_expectancy                                 0
# Fertility_rate_total_(births_per_woman)         0
# Adolescent_fertility_rate                       0
# Births_attended_by_skilled_health_staff         8
# Infant_Mortality_rate                           0
# Immunization_measles_(perc_of_children)         0
# Primary_completion_rate                         2
# School_enrollmentPrimary(perc)                  1
# School_enrollmentSecondary_(perc_)              0
# gender_parity_index                             1
# Forest_area_(sq_km)                             0
# ...

# %%
data['Primary_completion_rate']=data['Primary_completion_rate'].fillna(data['Primary_completion_rate'].mean())

# %%
data['gender_parity_index']=data['gender_parity_index'].fillna(data['gender_parity_index'].mean())

# %%
data['Energy_use_(kg_of_oil_)']=data['Energy_use_(kg_of_oil_)'].fillna(data['Energy_use_(kg_of_oil_)'].mean())

# %%
data['CO2_(metric_tons_per_capita)']=data['CO2_(metric_tons_per_capita)'].fillna(data['CO2_(metric_tons_per_capita)'].mean())

# %%
data['Revenue_(perc_of_GDP)']=data['Revenue_(perc_of_GDP)'].fillna(data['Revenue_(perc_of_GDP)'].mean())

# %%
data['Tax_revenue_(perc_of_GDP)']=data['Tax_revenue_(perc_of_GDP)'].fillna(data['Tax_revenue_(perc_of_GDP)'].mean())

# %%
data['Electricity_use(kWh_per_capita)']=data['Electricity_use(kWh_per_capita)'].fillna(data['Electricity_use(kWh_per_capita)'].mean())

# %%
data['School_enrollmentPrimary(perc)']=data['School_enrollmentPrimary(perc)'].fillna(data['School_enrollmentPrimary(perc)'].mean())

# %%
data.isnull().sum()
# Out:
# Year                                            0
# Population                                      0
# Population_growth(perc)                         0
# Area(sqkm)                                      0
# Population_density                              0
# Poverty_headcount_(perc_of_population)          0
# GNI(USdr)                                       0
# GNI_per_capita(USdr)                            0
# Life_expectancy                                 0
# Fertility_rate_total_(births_per_woman)         0
# Adolescent_fertility_rate                       0
# Births_attended_by_skilled_health_staff         8
# Infant_Mortality_rate                           0
# Immunization_measles_(perc_of_children)         0
# Primary_completion_rate                         0
# School_enrollmentPrimary(perc)                  0
# School_enrollmentSecondary_(perc_)              0
# gender_parity_index                             0
# Forest_area_(sq_km)                             0
# ...

# %%
data.skew()
# Out:
# <ipython-input-30-b3b431164adb>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# Population                                     -0.060341
# Population_growth(perc)                         0.495882
# Area(sqkm)                                      0.000000
# Population_density                             -0.060341
# Poverty_headcount_(perc_of_population)         -0.334589
# GNI(USdr)                                       0.286224
# GNI_per_capita(USdr)                            0.365373
# Life_expectancy                                -0.322409
# Fertility_rate_total_(births_per_woman)         0.755285
# Adolescent_fertility_rate                       0.433682
# Births_attended_by_skilled_health_staff              NaN
# Infant_Mortality_rate                           0.242394
# ...

# %%
economic=data[['GNI(USdr)', 'GNI_per_capita(USdr)',
       'GDP_(current_USdr)', 'GDP_growth_(annual_perc)',
       'Inflation(annual_perc)', 'Agriculture_sector(perc_of_GDP)',
       'Industrial_sector(perc_of_GDP)', 'Exports(perc_of_GDP)',
       'Imports(perc_of_GDP)', 'Gross_capital_formation_(perc_of_GDP)',
       'Revenue_(perc_of_GDP)','Tax_revenue_(perc_of_GDP)','Military_expenditure_(perc_of_GDP)',
       'Cellular_subscriptions_(per_100_people)',
       'High-technology_exports(perc)', 'Statistical_Capacity_Score',
       'Merchandise_trade(perc_of_GDP)', 'Net_terms_of_trade',
       'External_debt_stocks(current_USdr)', 'Total_debt_service',
       'Personal_remittances_received_(current_USdr)',
       'FDI(USdr)', 'development_aid_received(USdr)']]

# %%
social=data[['Population', 'Population_growth(perc)', 'Area(sqkm)',
       'Population_density', 'Poverty_headcount_(perc_of_population)','Life_expectancy',
       'Fertility_rate_total_(births_per_woman)', 'Adolescent_fertility_rate',
       'Infant_Mortality_rate','Immunization_measles_(perc_of_children)', 'Primary_completion_rate',
       'School_enrollmentPrimary(perc)', 'School_enrollmentSecondary_(perc_)',
       'gender_parity_index', 'Forest_area_(sq_km)',
       'Terrestrial_marine_areas', 'Annual_freshwater_withdrawals',
       'Urban_population_growth_(annual_perc)', 'Energy_use_(kg_of_oil_)',
       'CO2_(metric_tons_per_capita)', 'Electricity_use(kWh_per_capita)',
       'Net_migration(perc)','GDP_(current_USdr)']]

# %%
fin=data[['GNI(USdr)', 'GNI_per_capita(USdr)', 'GDP_(current_USdr)', 'GDP_growth_(annual_perc)', 'Inflation(annual_perc)']]

# %% [markdown]
# ECONOMIC INDICATORS
#
# 'Agriculture_sector(perc_of_GDP)',
#        'Industrial_sector(perc_of_GDP)', 'Exports(perc_of_GDP)',
#        'Imports(perc_of_GDP)', 'Gross_capital_formation_(perc_of_GDP)',
#        'Revenue_(perc_of_GDP)','Tax_revenue_(perc_of_GDP)','Military_expenditure_(perc_of_GDP)',
#        'Cellular_subscriptions_(per_100_people)',
#        'High-technology_exports(perc)', 'Statistical_Capacity_Score',
#        'Merchandise_trade(perc_of_GDP)', 'Net_terms_of_trade',

# %%
eco=data[['Agriculture_sector(perc_of_GDP)', 'Industrial_sector(perc_of_GDP)', 'Exports(perc_of_GDP)', 'Imports(perc_of_GDP)', 
      'Gross_capital_formation_(perc_of_GDP)', 'Revenue_(perc_of_GDP)','Tax_revenue_(perc_of_GDP)',
      'Military_expenditure_(perc_of_GDP)', 'Cellular_subscriptions_(per_100_people)', 'High-technology_exports(perc)', 
      'Statistical_Capacity_Score', 'Merchandise_trade(perc_of_GDP)', 'Net_terms_of_trade']]

# %% [markdown]
# FOREIGN AFFAIRSS
# 'External_debt_stocks(current_USdr)', 'Total_debt_service',
#        'Personal_remittances_received_(current_USdr)',
#        'FDI(USdr)', 'development_aid_received(USdr)','Net_migration(perc)'

# %%
fore=data[['External_debt_stocks(current_USdr)', 'Total_debt_service', 'Personal_remittances_received_(current_USdr)', 
       'FDI(USdr)', 'development_aid_received(USdr)','Net_migration(perc)']]

# %% [markdown]
# SOCIAL FACTOR:POPULATION
# 'Population', 'Population_growth(perc)', 'Area(sqkm)',
#        'Population_density', 'Poverty_headcount_(perc_of_population),'Urban_population_growth_(annual_perc)'

# %%
pop=data[['Population', 'Population_growth(perc)', 'Area(sqkm)', 'Population_density', 'Poverty_headcount_(perc_of_population)','Urban_population_growth_(annual_perc)']]

# %% [markdown]
# SOCIAL FACTOR:HEALTH
# Life_expectancy',
#        'Fertility_rate_total_(births_per_woman)', 'Adolescent_fertility_rate',
#        'Infant_Mortality_rate','Immunization_measles_(perc_of_children)'

# %%
health=data[['Life_expectancy', 'Fertility_rate_total_(births_per_woman)', 'Adolescent_fertility_rate', 'Infant_Mortality_rate','Immunization_measles_(perc_of_children)']]

# %% [markdown]
# RESOURCES:
# 'Energy_use_(kg_of_oil_)',
#        'CO2_(metric_tons_per_capita)', 'Electricity_use(kWh_per_capita)'

# %%
res=data[['Energy_use_(kg_of_oil_)', 'CO2_(metric_tons_per_capita)', 'Electricity_use(kWh_per_capita)']]

# %% [markdown]
# GEOGRAPHICAL:
# 'Forest_area_(sq_km)',
#        'Terrestrial_marine_areas', 'Annual_freshwater_withdrawals',

# %%
geo=data[['Forest_area_(sq_km)', 'Terrestrial_marine_areas', 'Annual_freshwater_withdrawals']]

# %% [markdown]
#  EDUCATION:
#  'Primary_completion_rate',
#        'School_enrollmentPrimary(perc)', 'School_enrollmentSecondary_(perc_)',
#        'gender_parity_index'

# %%
edu=data[['Primary_completion_rate', 'School_enrollmentPrimary(perc)', 'School_enrollmentSecondary_(perc_)', 'gender_parity_index']]

# %%
economic
# Out:
#       GNI(USdr)  GNI_per_capita(USdr)  GDP_(current_USdr)  \
# 0  1.700000e+12                  1360        1.820000e+12
# 1  1.870000e+12                  1480        1.830000e+12
# 2  1.940000e+12                  1520        1.860000e+12
# 3  2.020000e+12                  1560        2.040000e+12
# 4  2.100000e+12                  1600        2.100000e+12
# 5  2.230000e+12                  1680        2.290000e+12
# 6  2.440000e+12                  1820        2.650000e+12
# 7  2.710000e+12                  2010        2.700000e+12
# 8  2.870000e+12                  2100        2.830000e+12
# 9  2.640000e+12                  1910        2.670000e+12
#
#    GDP_growth_(annual_perc)  Inflation(annual_perc)  \
# 0                  5.241315                8.733580
# 1                  5.456389                7.934386
# 2                  6.386106                6.186504
# 3                  7.410228                3.331757
# 4                  7.996254                2.279588
# ...

# %%
social
# Out:
#    Population  Population_growth(perc)  Area(sqkm)  Population_density  \
# 0  1250287939                 1.288513     3287260          420.520700
# 1  1265780243                 1.231485     3287260          425.731367
# 2  1280842119                 1.182904     3287260          430.797265
# 3  1295600768                 1.145673     3287260          435.761175
# 4  1310152392                 1.116896     3287260          440.655455
# 5  1324517250                 1.090459     3287260          445.486918
# 6  1338676779                 1.063359     3287260          450.249321
# 7  1352642283                 1.037828     3287260          454.946466
# 8  1366417756                 1.013261     3287260          459.579696
# 9  1380004385                 0.989414     3287260          464.149410
#
#    Poverty_headcount_(perc_of_population)  Life_expectancy  \
# 0                                   22.50           67.130
# 1                                   21.70           67.545
# ...

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Year', y='GDP_(current_USdr)', data=data)

# %% [markdown]
# FINANCIAL INDICATORS
#
# GNI(USdr)', 'GNI_per_capita(USdr)',
#        'GDP_(current_USdr)', 'GDP_growth_(annual_perc)',
#        'Inflation(annual_perc)'

# %%
for i in fin.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = fin[i] , data = data, color='green')

# %%
for i in fin.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(fin[i])

# %%
for i in fin.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(fin[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in fin.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = fin[i] , data = data, color='green')

# %% [markdown]
# ECONOMIC INDICATORS
#
# 'Agriculture_sector(perc_of_GDP)',
#        'Industrial_sector(perc_of_GDP)', 'Exports(perc_of_GDP)',
#        'Imports(perc_of_GDP)', 'Gross_capital_formation_(perc_of_GDP)',
#        'Revenue_(perc_of_GDP)','Tax_revenue_(perc_of_GDP)','Military_expenditure_(perc_of_GDP)',
#        'Cellular_subscriptions_(per_100_people)',
#        'High-technology_exports(perc)', 'Statistical_Capacity_Score',
#        'Merchandise_trade(perc_of_GDP)', 'Net_terms_of_trade',

# %%
for i in eco.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = eco[i] , data = data, color='cyan')

# %%
for i in eco.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(eco[i])

# %%
for i in eco.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(eco[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in eco.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = eco[i] , data = data, color='cyan')

# %% [markdown]
# FOREIGN AFFAIRSS
# 'External_debt_stocks(current_USdr)', 'Total_debt_service',
#        'Personal_remittances_received_(current_USdr)',
#        'FDI(USdr)', 'development_aid_received(USdr)','Net_migration(perc)'

# %%
for i in fore.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = fore[i] , data = data, color='purple')

# %%
for i in fore.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(fore[i])

# %%
for i in eco.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(eco[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in fore.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = fore[i] , data = data, color='purple')

# %% [markdown]
# SOCIAL FACTOR:POPULATION
# 'Population', 'Population_growth(perc)', 'Area(sqkm)',
#        'Population_density', 'Poverty_headcount_(perc_of_population),'Urban_population_growth_(annual_perc)'

# %%
for i in pop.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = pop[i] , data = data, color='orange')

# %%
for i in pop.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(pop[i])

# %%
for i in pop.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(pop[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in pop.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = pop[i] , data = data, color='orange')

# %% [markdown]
# SOCIAL FACTOR:HEALTH Life_expectancy', 'Fertility_rate_total_(births_per_woman)', 'Adolescent_fertility_rate', 'Infant_Mortality_rate','Immunization_measles_(perc_of_children)'

# %%
for i in health.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = health[i] , data = data, color='blue')

# %%
for i in health.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(health[i])

# %%
for i in health.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(health[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in health.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = health[i] , data = data, color='blue')

# %% [markdown]
# RESOURCES: 'Energy_use_(kg_of_oil_)', 'CO2_(metric_tons_per_capita)', 'Electricity_use(kWh_per_capita)'

# %%
for i in res.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = res[i] , data = data, color='grey')

# %%
for i in res.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(res[i])

# %%
for i in res.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(res[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for i in res.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = res[i] , data = data, color='grey')

# %% [markdown]
# EDUCATION: 'Primary_completion_rate', 'School_enrollmentPrimary(perc)', 'School_enrollmentSecondary_(perc_)', 'gender_parity_index'

# %%
for i in edu.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = edu[i] , data = data, color='teal')

# %%
for i in edu.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(edu[i])

# %%
for i in edu.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(edu[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in edu.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = edu[i] , data = data, color='teal')

# %% [markdown]
# GEOGRAPHICAL: 'Forest_area_(sq_km)', 'Terrestrial_marine_areas', 'Annual_freshwater_withdrawals',

# %%
for i in geo.columns:
  plt.figure(figsize = (10,7))
  sns.barplot(x ='Year', y = geo[i] , data = data, color='gold')

# %%
for i in geo.columns:
  plt.figure(figsize = (6,6))
  sns.histplot(geo[i])

# %%
for i in geo.columns:
  plt.figure(figsize = (6,6))
  sns.boxplot(geo[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for i in geo.columns:
  plt.figure(figsize = (5,5))
  sns.scatterplot(x ='GDP_(current_USdr)', y = geo[i] , data = data, color='gold')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(economic.corr(),annot=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(social.corr(),annot=True)

# %%
corr=data.corr()
print(corr['GDP_(current_USdr)'].sort_values(ascending=False))
# Out:
# GDP_(current_USdr)                              1.000000
# GNI(USdr)                                       0.977045
# GNI_per_capita(USdr)                            0.970444
# Forest_area_(sq_km)                             0.954570
# Population_density                              0.953970
# Population                                      0.953970
# Immunization_measles_(perc_of_children)         0.948241
# Life_expectancy                                 0.945238
# Cellular_subscriptions_(per_100_people)         0.921373
# External_debt_stocks(current_USdr)              0.908158
# CO2_(metric_tons_per_capita)                    0.863326
# FDI(USdr)                                       0.741939
# School_enrollmentSecondary_(perc_)              0.731922
# Personal_remittances_received_(current_USdr)    0.729119
# Tax_revenue_(perc_of_GDP)                       0.591997
# Electricity_use(kWh_per_capita)                 0.586337
# ...

# %%
c_ab=abs(data.corr()['GDP_(current_USdr)'])

# %%
c_ab.sort_values(ascending=False)
# Out:
# GDP_(current_USdr)                              1.000000
# Poverty_headcount_(perc_of_population)          0.986195
# GNI(USdr)                                       0.977045
# GNI_per_capita(USdr)                            0.970444
# Forest_area_(sq_km)                             0.954570
# Adolescent_fertility_rate                       0.954080
# Population_density                              0.953970
# Population                                      0.953970
# Infant_Mortality_rate                           0.953027
# Immunization_measles_(perc_of_children)         0.948241
# Life_expectancy                                 0.945238
# Population_growth(perc)                         0.929003
# Cellular_subscriptions_(per_100_people)         0.921373
# Fertility_rate_total_(births_per_woman)         0.912618
# Industrial_sector(perc_of_GDP)                  0.910310
# External_debt_stocks(current_USdr)              0.908158
# ...

# %%
f=abs(data.corr()['GDP_(current_USdr)'][abs(data.corr()['GDP_(current_USdr)'])>0.4].drop(['GDP_(current_USdr)'])).index.tolist()
f
# Out:
# ['Population',
#  'Population_growth(perc)',
#  'Population_density',
#  'Poverty_headcount_(perc_of_population)',
#  'GNI(USdr)',
#  'GNI_per_capita(USdr)',
#  'Life_expectancy',
#  'Fertility_rate_total_(births_per_woman)',
#  'Adolescent_fertility_rate',
#  'Infant_Mortality_rate',
#  'Immunization_measles_(perc_of_children)',
#  'Primary_completion_rate',
#  'School_enrollmentPrimary(perc)',
#  'School_enrollmentSecondary_(perc_)',
#  'Forest_area_(sq_km)',
#  'Urban_population_growth_(annual_perc)',
#  'CO2_(metric_tons_per_capita)',
#  'Electricity_use(kWh_per_capita)',
#  'Inflation(annual_perc)',
#  'Industrial_sector(perc_of_GDP)',
#  'Exports(perc_of_GDP)',
#  'Imports(perc_of_GDP)',
#  'Gross_capital_formation_(perc_of_GDP)',
#  'Revenue_(perc_of_GDP)',
#  'Tax_revenue_(perc_of_GDP)',
#  'Cellular_subscriptions_(per_100_people)',
#  'High-technology_exports(perc)',
#  'Merchandise_trade(perc_of_GDP)',
#  'Net_terms_of_trade',
#  'External_debt_stocks(current_USdr)',
# ...

# %% [markdown]
# #MODEL

# %%
newdata=data[['Population',
 'Population_growth(perc)',
 'Population_density',
 'Poverty_headcount_(perc_of_population)',
 'GNI(USdr)',
 'GNI_per_capita(USdr)',
 'Life_expectancy',
 'Fertility_rate_total_(births_per_woman)',
 'Adolescent_fertility_rate',
 'Infant_Mortality_rate',
 'Immunization_measles_(perc_of_children)',
 'Primary_completion_rate',
 'School_enrollmentPrimary(perc)',
 'School_enrollmentSecondary_(perc_)',
 'Forest_area_(sq_km)',
 'Urban_population_growth_(annual_perc)',
 'CO2_(metric_tons_per_capita)',
 'Electricity_use(kWh_per_capita)',
 'Inflation(annual_perc)',
 'Industrial_sector(perc_of_GDP)',
 'Exports(perc_of_GDP)',
 'Imports(perc_of_GDP)',
 'Gross_capital_formation_(perc_of_GDP)',
 'Revenue_(perc_of_GDP)',
 'Tax_revenue_(perc_of_GDP)',
 'Cellular_subscriptions_(per_100_people)',
 'High-technology_exports(perc)',
 'Merchandise_trade(perc_of_GDP)',
 'Net_terms_of_trade',
 'External_debt_stocks(current_USdr)',
 'Personal_remittances_received_(current_USdr)',
 'FDI(USdr)']]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data2= scaler.fit_transform(newdata)
data2 = pd.DataFrame(data2,columns=newdata.columns)

# %%
data.shape
# Out:
# (10, 47)

# %%
plt.figure(figsize=(10,20))
sns.boxplot(data=data2,orient="h")

# %%
data2.head()
# Out:
#    Population  Population_growth(perc)  Population_density  \
# 0    0.000000                 1.000000            0.000000
# 1    0.119432                 0.809334            0.119432
# 2    0.235546                 0.646911            0.235546
# 3    0.349322                 0.522434            0.349322
# 4    0.461502                 0.426220            0.461502
#
#    Poverty_headcount_(perc_of_population)  GNI(USdr)  GNI_per_capita(USdr)  \
# 0                                  1.0000   0.000000              0.000000
# 1                                  0.9360   0.145299              0.162162
# 2                                  0.8808   0.205128              0.216216
# 3                                  0.7824   0.273504              0.270270
# 4                                  0.6960   0.341880              0.324324
#
#    Life_expectancy  Fertility_rate_total_(births_per_woman)  \
# 0         0.000000                                 1.000000
# ...

# %%
y = data['GDP_(current_USdr)']

# %%
y
# Out:
# 0    1.820000e+12
# 1    1.830000e+12
# 2    1.860000e+12
# 3    2.040000e+12
# 4    2.100000e+12
# 5    2.290000e+12
# 6    2.650000e+12
# 7    2.700000e+12
# 8    2.830000e+12
# 9    2.670000e+12
# Name: GDP_(current_USdr), dtype: float64

# %%
x= data2[['Population',
 'Population_growth(perc)',
 'Population_density',
 'Poverty_headcount_(perc_of_population)',
 'GNI(USdr)',
 'GNI_per_capita(USdr)',
 'Life_expectancy',
 'Fertility_rate_total_(births_per_woman)',
 'Adolescent_fertility_rate',
 'Infant_Mortality_rate',
 'Immunization_measles_(perc_of_children)',
 'Primary_completion_rate',
 'School_enrollmentPrimary(perc)',
 'School_enrollmentSecondary_(perc_)',
 'Forest_area_(sq_km)',
 'Urban_population_growth_(annual_perc)',
 'CO2_(metric_tons_per_capita)',
 'Electricity_use(kWh_per_capita)',
 'Inflation(annual_perc)',
 'Industrial_sector(perc_of_GDP)',
 'Exports(perc_of_GDP)',
 'Imports(perc_of_GDP)',
 'Gross_capital_formation_(perc_of_GDP)',
 'Revenue_(perc_of_GDP)',
 'Tax_revenue_(perc_of_GDP)',
 'Cellular_subscriptions_(per_100_people)',
 'High-technology_exports(perc)',
 'Merchandise_trade(perc_of_GDP)',
 'Net_terms_of_trade',
 'External_debt_stocks(current_USdr)',
 'Personal_remittances_received_(current_USdr)',
 'FDI(USdr)']]

# %%
x
# Out:
#    Population  Population_growth(perc)  Population_density  \
# 0    0.000000                 1.000000            0.000000
# 1    0.119432                 0.809334            0.119432
# 2    0.235546                 0.646911            0.235546
# 3    0.349322                 0.522434            0.349322
# 4    0.461502                 0.426220            0.461502
# 5    0.572243                 0.337833            0.572243
# 6    0.681400                 0.247228            0.681400
# 7    0.789062                 0.161866            0.789062
# 8    0.895259                 0.079731            0.895259
# 9    1.000000                 0.000000            1.000000
#
#    Poverty_headcount_(perc_of_population)  GNI(USdr)  GNI_per_capita(USdr)  \
# 0                                  1.0000   0.000000              0.000000
# 1                                  0.9360   0.145299              0.162162
# 2                                  0.8808   0.205128              0.216216
# ...

# %% [markdown]
# #MULTI LINEAR REGRESSION

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_reg=LinearRegression()
linear_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linear_reg.predict(x_test)
y_pred
# Out:
# array([2.89232672e+12, 1.83131783e+12])

# %%
from decimal import Decimal
for i in y_pred:
  print(Decimal(i))
# Out:
# 2892326721024.5830078125
# 1831317832478.8388671875

# %%
for i in y_test:
  print(Decimal(i))
# Out:
# 2830000000000
# 1830000000000

# %%
from sklearn.metrics import r2_score
acc1=r2_score(y_test,y_pred)
acc1
# Out:
# 0.992227286327763

# %%
data['GDP_(current_USdr)'].plot(figsize = (15, 5), alpha = 0.5)

# %% [markdown]
# #RANDOM FOREST REGRESSOR

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
rfc = RandomForestRegressor(n_estimators=100, max_depth=10)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10)

# %%
y2_pred=rfc.predict(x_test)
y2_pred
# Out:
# array([2.6205e+12, 1.9340e+12])

# %%
y_test
# Out:
# 8    2.830000e+12
# 1    1.830000e+12
# Name: GDP_(current_USdr), dtype: float64

# %%
for i in y2_pred:
  print(Decimal(i))
# Out:
# 2620500000000
# 1934000000000

# %%
acc=r2_score(y_test,y2_pred)
acc
# Out:
# 0.8905875

# %% [markdown]
# #XGBOOST REGRESSOR

# %%
import xgboost as xgb

# %%
xgbr = xgb.XGBRegressor(learning_rate=0.1, max_depth=3, n_estimators=100,random_state=0)
print(xgbr)
# Out:
# XGBRegressor()

# %%
xgbr.fit(x_train,y_train)

# %%
y3_pred=xgbr.predict(x_test)
y3_pred
# Out:
# array([2.6930832e+12, 1.8598460e+12], dtype=float32)

# %%
acc3=r2_score(y_test,y3_pred)
acc3
# Out:
# 0.9607259936753794

# %%
print("ACCURACY")
report = [['multilinear regression',acc1],['random forest reggresor',acc],['XGboost regressor',acc3]]
df = pd.DataFrame(report,columns=['Model','Accuracy'])
df
# Out:
# ACCURACY
#                      Model  Accuracy
# 0   multilinear regression  0.992227
# 1  random forest reggresor  0.890587
# 2        XGboost regressor  0.960726
